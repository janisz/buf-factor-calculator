# %%
import pandas as pd
import networkx as nx
# %matplotlib inline

# %%
df = pd.read_csv('bus_factor.csv', parse_dates=True)

# %%
df['ratio'] = df['bus_factor']/df['authors']

# %%
print(df.describe())
# Out:
#         bus_factor      authors       ratio
# count   120.000000   120.000000  120.000000
# mean    112.908333   396.066667    0.296755
# std     188.607012   660.543051    0.042482
# min       1.000000     2.000000    0.156863
# 25%      39.750000   136.500000    0.275766
# 50%      69.500000   230.000000    0.295603
# 75%     132.250000   456.250000    0.319437
# max    1865.000000  6339.000000    0.500000

# %%
df.hist(column='ratio')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc91d961290>]], dtype=object)

# %%
df.hist(column='ratio', bins=10, range=(0,0.5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fc91d7c5d10>]], dtype=object)

# %%
df['ratio'].plot.hist(bins=20)

# %%
main_dev = pd.read_csv('data/repos/apache/mesos/main-dev.csv', parse_dates=True)

# %%
main_dev = pd.read_csv('data/repos/apache/mesos/main-dev.csv', parse_dates=True)
dev = main_dev[['main-dev', 'ownership']].groupby('main-dev').sum()  / summary['value'][2]
dev = dev / dev.sum()
dev.reset_index().sort_values(by='ownership', ascending=False)
# Out:
#                    main-dev  ownership
# 13         Benjamin Hindman   0.863639
# 54  Matei Alexandru Zaharia   0.040439
# 43                   Jie Yu   0.011135
# 12         Benjamin Bannier   0.006880
# 76               Vinod Kone   0.006724
# 14          Benjamin Mahler   0.005400
# 48                Joseph Wu   0.004535
# 2              Alex Clemmer   0.004512
# 63                    Rossi   0.004386
# 34             Gilbert Song   0.004255
# 72             Timothy Chen   0.003261
# 47     Joris Van Remoortere   0.002703
# 37               Ian Downes   0.002541
# 24              Dave Lester   0.002425
# 50              Kevin Klues   0.002399
# 49               Kapil Arya   0.002332
# 45            Jojy Varghese   0.002329
# 71           Till Toenshoff   0.002165
# 4           Alexander Rojas   0.002135
# 5       Alexander Rukletsov   0.001769
# 42             Jiang Yan Xu   0.001759
# 38           Isabel Jimenez   0.001587
# 29            Dominic Hamon   0.001542
# 62               Ross Allen   0.001363
# 56             Michael Park   0.001185
# 67            Steve Niemitz   0.001032
# 57              Neil Conway   0.000927
# 80           haosdent huang   0.000817
# 51                Lily Chen   0.000803
# 70        Thomas Rampelberg   0.000757
# ..                      ...        ...
# 64                Shuai Lin   0.000178
# 52                M Lawindi   0.000161
# 35                Greg Mann   0.000150
# 16         Brenden Matthews   0.000147
# 77                Yong Tang   0.000147
# 17            Charles Reiss   0.000147
# 27             Diana Arroyo   0.000146
# 18           Charlie Carson   0.000139
# 23              Dario Bazan   0.000132
# 69          Thomas Marshall   0.000130
# 74               Tobi Knaup   0.000126
# 25           David Forsythe   0.000114
# 7            Andy Konwinski   0.000106
# 81                 mlawindi   0.000074
# 41             Jan Schlicht   0.000074
# 55            Michael Lunøe   0.000074
# 46           Jonathon Rossi   0.000074
# 33           Gabriel Monroy   0.000074
# 30                  Elsmore   0.000074
# 82                   niklas   0.000062
# 66             Stan Teresen   0.000060
# 61  Ricardo Cervera-Navarro   0.000060
# 11               Ben Mahler   0.000054
# 26           David Robinson   0.000051
# 28             Disha  Singh   0.000041
# 75             Tom Galloway   0.000039
# 39             Jake Farrell   0.000036
# 53          Marco Massenzio   0.000017
# 65                     Sipe   0.000000
# 32          Felix Abecassis   0.000000
#
# [83 rows x 2 columns]

# %%
# Out:
#                                                   entity  \
# 0                                          .clang-format
# 1                                             .gitignore
# 2                                    .gitignore-template
# 3               .gitignore-template => support/gitignore
# 4                                            .travis.yml
# 5                                3rdparty/CMakeLists.txt
# 6                                   3rdparty/Makefile.am
# 7                                3rdparty/boto-2.0b2.zip
# 8            3rdparty/cmake/Mesos3rdpartyConfigure.cmake
# 9                          3rdparty/cmake/Versions.cmake
# 10                           3rdparty/leveldb-1.4.tar.gz
# 11                                3rdparty/leveldb.patch
# 12                               3rdparty/leveldb.tar.gz
# 13           3rdparty/libprocess/3rdparty/CMakeLists.txt
# 14              3rdparty/libprocess/3rdparty/Makefile.am
# 15      3rdparty/libprocess/3rdparty/boost-1.53.0.tar.gz
# 16        3rdparty/libprocess/3rdparty/glog-0.3.1.tar.gz
# 17         3rdparty/libprocess/3rdparty/glog-0.3.3.patch
# 18        3rdparty/libprocess/3rdparty/glog-0.3.3.tar.gz
# 19       3rdparty/libprocess/3rdparty/gmock-1.6.0.tar.gz
# 20       3rdparty/libprocess/3rdparty/gmock-1.7.0.tar.gz
# 21      3rdparty/libprocess/3rdparty/gmock_sources.cc.in
# 22     3rdparty/libprocess/3rdparty/http-parser/CMake...
# 23         3rdparty/libprocess/3rdparty/libev-4.15.patch
# 24     3rdparty/libprocess/3rdparty/picojson-1.3.0.ta...
# 25     3rdparty/libprocess/3rdparty/picojson-4f93734....
# 26     3rdparty/libprocess/3rdparty/protobuf-2.4.1.ta...
# 27     3rdparty/libprocess/3rdparty/protobuf-2.5.0.ta...
# 28     3rdparty/libprocess/3rdparty/ry-http-parser-1c...
# 29        3rdparty/libprocess/3rdparty/stout/Makefile.am
# ...                                                  ...
# 32172  {third_party => 3rdparty}/libprocess/src/synch...
# 32173  {third_party => 3rdparty}/libprocess/src/test-...
# 32174  {third_party => 3rdparty}/libprocess/src/test-...
# 32175  {third_party => 3rdparty}/libprocess/src/tests...
# 32176  {third_party => 3rdparty}/libprocess/src/tests...
# 32177  {third_party => 3rdparty}/libprocess/src/tests...
# 32178  {third_party => 3rdparty}/libprocess/src/tests...
# 32179  {third_party => 3rdparty}/libprocess/src/tests...
# 32180  {third_party => 3rdparty}/libprocess/src/tests...
# 32181  {third_party => 3rdparty}/libprocess/src/tests...
# 32182  {third_party => 3rdparty}/libprocess/src/tests...
# 32183  {third_party => 3rdparty}/libprocess/src/timer...
# 32184  {third_party => 3rdparty}/libprocess/src/timer...
# 32185              {third_party => 3rdparty}/versions.am
# 32186   {third_party => 3rdparty}/zookeeper-3.3.4.tar.gz
# 32187   {third_party => src/webui}/bottle-0.5.6/PKG-INFO
# 32188     {third_party => src/webui}/bottle-0.5.6/README
# 32189  {third_party => src/webui}/bottle-0.5.6/bottle.py
# 32190   {third_party => src/webui}/bottle-0.5.6/setup.py
# 32191  {third_party => src/webui}/bottle-0.5.6/test/t...
# 32192  {third_party => src/webui}/bottle-0.5.6/test/t...
# 32193  {third_party => src/webui}/bottle-0.5.6/test/t...
# 32194  {third_party => src/webui}/bottle-0.5.6/test/t...
# 32195  {third_party => src/webui}/bottle-0.5.6/test/t...
# 32196  {third_party/libprocess => 3rdparty/libprocess...
# 32197  {third_party/libprocess => 3rdparty/libprocess...
# 32198  {third_party/libprocess => 3rdparty/libprocess...
# 32199  {third_party/libprocess/3rdparty/stout => 3rdp...
# 32200  {third_party/libprocess/3rdparty/stout => 3rdp...
# 32201  {third_party/libprocess/3rdparty/stout => 3rdp...
#
#                    main-dev  added  total-added  ownership
# 0              Michael Park      1            1       1.00
# 1          Benjamin Hindman    397          397       1.00
# 2          Benjamin Hindman     23           35       0.66
# 3              Michael Park      0            0       0.00
# 4             Dominic Hamon     47           47       1.00
# 5              Alex Clemmer     76          109       0.70
# 6         Timothy St. Clair     21           49       0.43
# 7         Timothy St. Clair      0            0       0.00
# 8                 M Lawindi     82          132       0.62
# 9              Alex Clemmer     12           14       0.86
# 10             Diana Arroyo      0            0       0.00
# 11           Till Toenshoff     30           30       1.00
# 12        Timothy St. Clair      0            0       0.00
# 13             Alex Clemmer    473          568       0.83
# 14        Timothy St. Clair     81          206       0.39
# 15                   Jie Yu      0            0       0.00
# 16          Benjamin Mahler      0            0       0.00
# 17         Benjamin Hindman    105          140       0.75
# 18          Benjamin Mahler      0            0       0.00
# 19           haosdent huang      0            0       0.00
# 20           haosdent huang      0            0       0.00
# 21        Timothy St. Clair     19           19       1.00
# 22             Alex Clemmer     35           35       1.00
# 23             Cody Maloney     12           12       1.00
# 24     Joris Van Remoortere      0            0       0.00
# 25         Benjamin Hindman      0            0       0.00
# 26         Benjamin Hindman      0            0       0.00
# 27         Benjamin Hindman      0            0       0.00
# 28                 mlawindi     28           28       1.00
# 29          Benjamin Mahler     16           89       0.18
# ...                     ...    ...          ...        ...
# 32172      Benjamin Hindman      0            0       0.00
# 32173      Benjamin Hindman      0            0       0.00
# 32174      Benjamin Hindman      0            0       0.00
# 32175      Benjamin Hindman      0            0       0.00
# 32176      Benjamin Hindman      0            0       0.00
# 32177      Benjamin Hindman      0            0       0.00
# 32178      Benjamin Hindman      0            0       0.00
# 32179      Benjamin Hindman      0            0       0.00
# 32180      Benjamin Hindman      0            0       0.00
# 32181      Benjamin Hindman      0            0       0.00
# 32182      Benjamin Hindman      0            0       0.00
# 32183      Benjamin Hindman      0            0       0.00
# 32184      Benjamin Hindman      0            0       0.00
# 32185      Benjamin Hindman      2            2       1.00
# 32186      Benjamin Hindman      0            0       0.00
# 32187      Benjamin Hindman      0            0       0.00
# 32188      Benjamin Hindman      0            0       0.00
# 32189      Benjamin Hindman      0            0       0.00
# 32190      Benjamin Hindman      0            0       0.00
# 32191      Benjamin Hindman      0            0       0.00
# 32192      Benjamin Hindman      0            0       0.00
# 32193      Benjamin Hindman      0            0       0.00
# 32194      Benjamin Hindman      0            0       0.00
# 32195      Benjamin Hindman      0            0       0.00
# 32196      Benjamin Hindman      0            0       0.00
# 32197      Benjamin Hindman      0            0       0.00
# 32198      Benjamin Hindman      0            0       0.00
# 32199      Benjamin Hindman      0            0       0.00
# 32200      Benjamin Hindman      0            0       0.00
# 32201      Benjamin Hindman      0            0       0.00
#
# [32202 rows x 5 columns]
